# %% [markdown]
# Ниже мы рассмотрим методы кодирования, обозначенные в блок-схеме. Для кодирования категориальных признаков мы будем использовать библиотеку category_encoders. Это удобная библиотека для кодирования категориальных переменных различными методами.

# %%
# pip install category_encoders

# %%
import category_encoders as ce

# %% [markdown]
# # Порядковое кодирование. Ordinal Encoding

# %% [markdown]
# В порядковой кодировке признаков каждому строковому значению присваивается значение в виде целого числа, свойственного для конкретного значения строки.
#
# Результат кодирования порядкового признака size будет выглядеть так: каждому строковому значению присваивается значение в виде целого числа.

# %% [markdown]
# <center> <img src = https://lms.skillfactory.ru/assets/courseware/v1/8b7f78d8227dfe3b37afbdb4bfea968d/asset-v1:SkillFactory+DSPR-2.0+14JULY2021+type@asset+block/dst-eda-3-9.png alt="drawing" style="width:400px;">

# %%
import pandas as pd
# инициализируем информацию об одежде
clothing_list = [
    ['xxs', 'dress'],
    ['xxs', 'skirt'],
    ['xs', 'dress'],
    ['s', 'skirt'],
    ['m', 'dress'],
    ['l', 'shirt'],
    ['s', 'coat'],
    ['m', 'coat'],
    ['xxl', 'shirt'],
    ['l', 'dress']
]

clothing = pd.DataFrame(clothing_list, columns = ['size',  'type'])
clothing
# Out:
#   size   type
# 0  xxs  dress
# 1  xxs  skirt
# 2   xs  dress
# 3    s  skirt
# 4    m  dress
# 5    l  shirt
# 6    s   coat
# 7    m   coat
# 8  xxl  shirt
# 9    l  dress

# %%
ord_encoder = ce.OrdinalEncoder()
data_bin = ord_encoder.fit_transform(clothing[['size']])
clothing = pd.concat([clothing, data_bin], axis=1)

clothing
# Out:
#    size   type  size
# 0   xxs  dress     1
# 1   xxs  skirt     1
# 2    xs  dress     2
# 3     s  skirt     3
# 4     m  dress     4
# 5     l  shirt     5
# 6     s   coat     3
# 7     m   coat     4
# 8   xxl  shirt     6
# 9     l  dress     5

# %%
data = pd.read_csv('data/wine_edited.csv', sep='\t')

# %%
ord_encoder = ce.OrdinalEncoder(cols=['year'])
data_bin = ord_encoder.fit_transform(data[['year']])
data = pd.concat([data, data_bin], axis=1)

data
# Out:
#         Unnamed: 0.1  Unnamed: 0   country  \
# 0                  0           0     Italy
# 1                  1           1  Portugal
# 2                  2           2        US
# 3                  3           3        US
# 4                  4           4        US
# ...              ...         ...       ...
# 129967        129966      129966   Germany
# 129968        129967      129967        US
# 129969        129968      129968    France
# 129970        129969      129969    France
# 129971        129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129967  Notes of honeysuckle and cantaloupe sweeten th...
# 129968  Citation is given as much as a decade of bottl...
# 129969  Well-drained gravel soil gives this wine its c...
# 129970  A dry style of Pinot Gris, this is crisp with ...
# 129971  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points      price  \
# 0                                 Vulkà Bianco      87  35.363389
# 1                                     Avidagos      87  15.000000
# 2                                      unknown      87  14.000000
# 3                         Reserve Late Harvest      87  13.000000
# 4           Vintner's Reserve Wild Child Block      87  65.000000
# ...                                        ...     ...        ...
# 129967  Brauneberger Juffer-Sonnenuhr Spätlese      90  28.000000
# 129968                                 unknown      90  75.000000
# 129969                                   Kritt      90  30.000000
# 129970                                 unknown      90  32.000000
# 129971           Lieu-dit Harth Cuvée Caroline      90  21.000000
#
#                  province             region_1         taster_name  ...  \
# 0       Sicily & Sardinia                 Etna       Kerin O’Keefe  ...
# 1                   Douro              unknown          Roger Voss  ...
# 2                  Oregon    Willamette Valley        Paul Gregutt  ...
# 3                Michigan  Lake Michigan Shore  Alexander Peartree  ...
# 4                  Oregon    Willamette Valley        Paul Gregutt  ...
# ...                   ...                  ...                 ...  ...
# 129967              Mosel              unknown  Anna Lee C. Iijima  ...
# 129968             Oregon               Oregon        Paul Gregutt  ...
# 129969             Alsace               Alsace          Roger Voss  ...
# 129970             Alsace               Alsace          Roger Voss  ...
# 129971             Alsace               Alsace          Roger Voss  ...
#
#        price_round    year is_usa is_france  is_italy  old_wine  \
# 0               35  2013.0      0         0         1         0
# 1               15  2011.0      0         0         0         0
# 2               14  2013.0      1         0         0         0
# 3               13  2013.0      1         0         0         0
# 4               65  2012.0      1         0         0         0
# ...            ...     ...    ...       ...       ...       ...
# 129967          28  2013.0      0         0         0         0
# 129968          75  2004.0      1         0         0         1
# 129969          30  2013.0      0         1         0         0
# 129970          32  2012.0      0         1         0         0
# 129971          21  2012.0      0         1         0         0
#
#                       locality   population       area  year
# 0                         Etna   59,097,904   301230.0     1
# 1                        Douro   10,347,892    92391.0     2
# 2            Willamette Valley  333,022,386  9372610.0     1
# 3          Lake Michigan Shore  333,022,386  9372610.0     1
# 4            Willamette Valley  333,022,386  9372610.0     3
# ...                        ...          ...        ...   ...
# 129967  Erben Müller-Burggraef   83,129,285   357022.0     1
# 129968                  Oregon  333,022,386  9372610.0    12
# 129969                  Alsace   68,035,000   547030.0     1
# 129970                  Alsace   68,035,000   547030.0     3
# 129971                  Alsace   68,035,000   547030.0     3
#
# [129972 rows x 24 columns]

# %% [markdown]
# # Однократное кодирование. One-Hot Encoding

# %% [markdown]
# Однократное кодирование (его ещё часто называют «горячим») является автоматизированным кодированием, которое мы делали в юните Создание признаков. Для каждой новой категории создается новый бинарный признак. Значение 1 в этих признаках проставляется там, где значение исходного признака равно этой категории.

# %% [markdown]
# <center> <img src = https://lms.skillfactory.ru/assets/courseware/v1/cf911b8140617ec467e9de45c883669b/asset-v1:SkillFactory+DSPR-2.0+14JULY2021+type@asset+block/dst-eda-3-11.png alt="drawing" style="width:400px;">

# %% [markdown]
# На рисунке изображено кодирование колонки color со значениями red, green, blue. Для каждого значения создаётся новый бинарный признак: red -> color_red, blue -> color_blue, green -> color_green, и проставляются значения исходного признака.
#
# Этот способ кодирования понятен, хорошо работает как на номинальных, так и на порядковых признаках. Однако существует один минус: количество созданных признаков равно количеству уникальных значений категориального признака.

# %%
encoder = ce.OneHotEncoder(cols=['type'], use_cat_names=True) # указываем столбец для кодирования
type_bin = encoder.fit_transform(clothing['type'])
clothing = pd.concat([clothing, type_bin], axis=1)

clothing
# Out:
#    size   type  size  type_dress  type_skirt  type_shirt  type_coat
# 0   xxs  dress     1           1           0           0          0
# 1   xxs  skirt     1           0           1           0          0
# 2    xs  dress     2           1           0           0          0
# 3     s  skirt     3           0           1           0          0
# 4     m  dress     4           1           0           0          0
# 5     l  shirt     5           0           0           1          0
# 6     s   coat     3           0           0           0          1
# 7     m   coat     4           0           0           0          1
# 8   xxl  shirt     6           0           0           1          0
# 9     l  dress     5           1           0           0          0

# %%
clothing_dummies = pd.get_dummies(clothing, columns=['type'])
clothing_dummies
# Out:
#    size  size  type_dress  type_skirt  type_shirt  type_coat  type_coat  \
# 0   xxs     1           1           0           0          0          0
# 1   xxs     1           0           1           0          0          0
# 2    xs     2           1           0           0          0          0
# 3     s     3           0           1           0          0          0
# 4     m     4           1           0           0          0          0
# 5     l     5           0           0           1          0          0
# 6     s     3           0           0           0          1          1
# 7     m     4           0           0           0          1          1
# 8   xxl     6           0           0           1          0          0
# 9     l     5           1           0           0          0          0
#
#    type_dress  type_shirt  type_skirt
# 0           1           0           0
# 1           0           0           1
# 2           1           0           0
# 3           0           0           1
# 4           1           0           0
# 5           0           1           0
# 6           0           0           0
# 7           0           0           0
# 8           0           1           0
# 9           1           0           0

# %%
data = pd.read_csv('data/wine_edited.csv', sep='\t')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129972 entries, 0 to 129971
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0.1           129972 non-null  int64
#  1   Unnamed: 0             129972 non-null  int64
#  2   country                129909 non-null  object
#  3   description            129972 non-null  object
#  4   designation            129972 non-null  object
#  5   points                 129972 non-null  int64
#  6   price                  129972 non-null  float64
#  7   province               129909 non-null  object
#  8   region_1               129972 non-null  object
#  9   taster_name            129972 non-null  object
#  10  taster_twitter_handle  129972 non-null  object
#  11  title                  129972 non-null  object
#  12  variety                129971 non-null  object
#  13  winery                 129972 non-null  object
#  14  price_round            129972 non-null  int64
#  15  year                   125363 non-null  float64
#  16  is_usa                 129972 non-null  int64
#  17  is_france              129972 non-null  int64
#  18  is_italy               129972 non-null  int64
#  19  old_wine               129972 non-null  int64
#  20  locality               119450 non-null  object
#  21  population             129823 non-null  object
#  22  area                   129835 non-null  float64
# dtypes: float64(3), int64(8), object(12)
# memory usage: 22.8+ MB

# %% [markdown]
# * в сете 23 признака. Закодируем его, используя One-Hot Encoding.

# %%
encoder = ce.OneHotEncoder(cols=['taster_name'], use_cat_names=True) # указываем столбец для кодирования
type_bin = encoder.fit_transform(data['taster_name'])
data = pd.concat([data, type_bin], axis=1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129972 entries, 0 to 129971
# Data columns (total 43 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unnamed: 0.1                    129972 non-null  int64
#  1   Unnamed: 0                      129972 non-null  int64
#  2   country                         129909 non-null  object
#  3   description                     129972 non-null  object
#  4   designation                     129972 non-null  object
#  5   points                          129972 non-null  int64
#  6   price                           129972 non-null  float64
#  7   province                        129909 non-null  object
#  8   region_1                        129972 non-null  object
#  9   taster_name                     129972 non-null  object
#  10  taster_twitter_handle           129972 non-null  object
#  11  title                           129972 non-null  object
#  12  variety                         129971 non-null  object
#  13  winery                          129972 non-null  object
#  14  price_round                     129972 non-null  int64
#  15  year                            125363 non-null  float64
#  16  is_usa                          129972 non-null  int64
#  17  is_france                       129972 non-null  int64
#  18  is_italy                        129972 non-null  int64
#  19  old_wine                        129972 non-null  int64
#  20  locality                        119450 non-null  object
#  21  population                      129823 non-null  object
#  22  area                            129835 non-null  float64
#  23  taster_name_Kerin O’Keefe       129972 non-null  int64
#  24  taster_name_Roger Voss          129972 non-null  int64
#  25  taster_name_Paul Gregutt        129972 non-null  int64
#  26  taster_name_Alexander Peartree  129972 non-null  int64
#  27  taster_name_Michael Schachner   129972 non-null  int64
#  28  taster_name_Anna Lee C. Iijima  129972 non-null  int64
#  29  taster_name_Virginie Boone      129972 non-null  int64
#  30  taster_name_Matt Kettmann       129972 non-null  int64
#  31  taster_name_unknown             129972 non-null  int64
#  32  taster_name_Sean P. Sullivan    129972 non-null  int64
#  33  taster_name_Jim Gordon          129972 non-null  int64
#  34  taster_name_Joe Czerwinski      129972 non-null  int64
#  35  taster_name_Anne Krebiehl MW    129972 non-null  int64
#  36  taster_name_Lauren Buzzeo       129972 non-null  int64
#  37  taster_name_Mike DeSimone       129972 non-null  int64
#  38  taster_name_Jeff Jenssen        129972 non-null  int64
#  39  taster_name_Susan Kostrzewa     129972 non-null  int64
#  40  taster_name_Carrie Dykes        129972 non-null  int64
#  41  taster_name_Fiona Adams         129972 non-null  int64
#  42  taster_name_Christina Pickard   129972 non-null  int64
# dtypes: float64(3), int64(28), object(12)
# memory usage: 42.6+ MB

# %% [markdown]
# # Двоичное кодирование

# %% [markdown]
# Принцип двоичного кодирования похож на однократное кодирование, но создаёт меньше столбцов. При однократном кодировании признака с количеством уникальных категорий 100 шт. мы создадим 100 новых признаков, а при двоичном кодирования мы сгенерируем всего 7 признаков.
#
# На рисунке ниже представлен алгоритм бинарного кодирования температуры воздуха.

# %% [markdown]
# <center> <img src = https://lms.skillfactory.ru/assets/courseware/v1/257600c912d08d49d9c9f7e6e6c02f6c/asset-v1:SkillFactory+DSPR-2.0+14JULY2021+type@asset+block/dst-eda-3-14.png alt="drawing" style="width:400px;">

# %% [markdown]
# 1. Сначала признак кодируется в числовое представление, как мы делали это при кодировании порядковых признаков: hot — 1, cold — 2, … и так далее.
#
# 2. Затем каждое числовое представление, выраженное целым числом, переводится в двоичный код: 1 – 001, 2 – 010, 3 – 011,... и так далее.
#
# 3. Затем для каждого двоичного представления создаются новые признаки. В нашем случае двоичное представления уместилось в три числа, поэтому итогом стало создание трёх новых признаков.

# %%
bin_encoder = ce.BinaryEncoder(cols=['type']) # указываем столбец для кодирования
type_bin = bin_encoder.fit_transform(clothing['type'])
clothing = pd.concat([clothing, type_bin], axis=1)

clothing
# Out:
#    size   type  size  type_dress  type_skirt  type_shirt  type_coat  type_0  \
# 0   xxs  dress     1           1           0           0          0       0
# 1   xxs  skirt     1           0           1           0          0       0
# 2    xs  dress     2           1           0           0          0       0
# 3     s  skirt     3           0           1           0          0       0
# 4     m  dress     4           1           0           0          0       0
# 5     l  shirt     5           0           0           1          0       0
# 6     s   coat     3           0           0           0          1       1
# 7     m   coat     4           0           0           0          1       1
# 8   xxl  shirt     6           0           0           1          0       0
# 9     l  dress     5           1           0           0          0       0
#
#    type_1  type_2
# 0       0       1
# 1       1       0
# 2       0       1
# 3       1       0
# 4       0       1
# 5       1       1
# 6       0       0
# 7       0       0
# 8       1       1
# 9       0       1

# %%
data = pd.read_csv('data/wine_cleared.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             129971 non-null  int64
#  1   country                129908 non-null  object
#  2   description            129971 non-null  object
#  3   designation            129971 non-null  object
#  4   points                 129971 non-null  int64
#  5   price                  129971 non-null  float64
#  6   province               129908 non-null  object
#  7   region_1               129971 non-null  object
#  8   taster_name            129971 non-null  object
#  9   taster_twitter_handle  129971 non-null  object
#  10  title                  129971 non-null  object
#  11  variety                129970 non-null  object
#  12  winery                 129971 non-null  object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 12.9+ MB

# %% [markdown]
# * в сете 13 признаков. Закодируем признак country двоичным способом.

# %%
bin_encoder = ce.BinaryEncoder(cols=['country']) # указываем столбец для кодирования
type_bin = bin_encoder.fit_transform(data['country'])
data = pd.concat([data, type_bin], axis=1)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             129971 non-null  int64
#  1   country                129908 non-null  object
#  2   description            129971 non-null  object
#  3   designation            129971 non-null  object
#  4   points                 129971 non-null  int64
#  5   price                  129971 non-null  float64
#  6   province               129908 non-null  object
#  7   region_1               129971 non-null  object
#  8   taster_name            129971 non-null  object
#  9   taster_twitter_handle  129971 non-null  object
#  10  title                  129971 non-null  object
#  11  variety                129970 non-null  object
#  12  winery                 129971 non-null  object
#  13  country_0              129971 non-null  int64
#  14  country_1              129971 non-null  int64
#  15  country_2              129971 non-null  int64
#  16  country_3              129971 non-null  int64
#  17  country_4              129971 non-null  int64
#  18  country_5              129971 non-null  int64
# dtypes: float64(1), int64(8), object(10)
# memory usage: 18.8+ MB

# %% [markdown]
# На основе изученного материала определите подходящий способ кодирования признака taster_twitter_handle из датасета винных обзоров и закодируйте его.

# %%
data = pd.read_csv('data/wine_cleared.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             129971 non-null  int64
#  1   country                129908 non-null  object
#  2   description            129971 non-null  object
#  3   designation            129971 non-null  object
#  4   points                 129971 non-null  int64
#  5   price                  129971 non-null  float64
#  6   province               129908 non-null  object
#  7   region_1               129971 non-null  object
#  8   taster_name            129971 non-null  object
#  9   taster_twitter_handle  129971 non-null  object
#  10  title                  129971 non-null  object
#  11  variety                129970 non-null  object
#  12  winery                 129971 non-null  object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 12.9+ MB

# %%
data['taster_twitter_handle'].value_counts().count()
# Out:
# 16

# %% [markdown]
# Признак taster_twitter_handle номинальный и имеет много уникальных значений (более 15). Следует выбрать binary encoder.

# %%
bin_encoder = ce.BinaryEncoder(cols=['taster_twitter_handle']) # указываем столбец для кодирования
type_bin = bin_encoder.fit_transform(data['taster_twitter_handle']) # таблица с признаками, которые добавляются
data = pd.concat([data, type_bin], axis=1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Unnamed: 0               129971 non-null  int64
#  1   country                  129908 non-null  object
#  2   description              129971 non-null  object
#  3   designation              129971 non-null  object
#  4   points                   129971 non-null  int64
#  5   price                    129971 non-null  float64
#  6   province                 129908 non-null  object
#  7   region_1                 129971 non-null  object
#  8   taster_name              129971 non-null  object
#  9   taster_twitter_handle    129971 non-null  object
#  10  title                    129971 non-null  object
#  11  variety                  129970 non-null  object
#  12  winery                   129971 non-null  object
#  13  taster_twitter_handle_0  129971 non-null  int64
#  14  taster_twitter_handle_1  129971 non-null  int64
#  15  taster_twitter_handle_2  129971 non-null  int64
#  16  taster_twitter_handle_3  129971 non-null  int64
#  17  taster_twitter_handle_4  129971 non-null  int64
# dtypes: float64(1), int64(7), object(10)
# memory usage: 17.8+ MB

# %% [markdown]
# В этот раз меньше новых признаков, т.к. не у всех есть страница в соц сетях

# %%
ord_encoder = ce.OrdinalEncoder()
data_bin = ord_encoder.fit_transform(list_of_dicts[['payment_type']])
list_of_dicts = pd.concat([list_of_dicts, data_bin], axis=1)
